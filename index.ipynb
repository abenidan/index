# %% [markdown]
#                                                     JINKA UNIVERSITY
#                                                     COLLEGE OF NATURAL AND COMPUTATIONAL SCIENCE OF
#                                                     COMPUTER SCIENCE
#
#                                                     PROJECT TITTLE : ONLINE TRANSACTION FRAUD DETECTION
#
#
#
#
#                                    - NAME : ABENEZER DANIEL
#                                    - INDIVIDUAL PROJECT
#                                    - ID NO. : UGR/13152/14
#
#
#                                    -INSTRUCTOR NAME :
#                                    -SUBMISSION DATE :
#
#
#                                                                                                                                                                                      JINKA-ETHIOPIA
#                                                                                                                                                                                      (JKU)

# %% [markdown]
#  1.*Introduction
#
# Online TRANSACTION is the most popular transaction method in the world today. However, with an increase in online payments also comes a rise in payment fraud. The objective of this study is to identify fraudulent and non-fraudulent payments. The dataset is collected from Kaggle, which contains historical information about fraudulent transactions which can be used to detect fraud in online payments.
#
# The dataset consists of 10 variables:
#
# step: represents a unit of time where 1 step equals 1
#  hour
# type: type of online trans
# action
# amount: the amount of the tran
# saction
# nameOrig: customer starting the tra
# nsaction
# oldbalanceOrg: balance before the tr
# ansaction
# newbalanceOrig: balance after the t
# ransaction
# nameDest: recipient of the
# transaction
# oldbalanceDest: initial balance of recipient before the
#  transaction
# newbalanceDest: the new balance of recipient after th
# e transaction
# isFraud: fraud transaction

# %% [markdown]
# splitting the dataud transaction

# %% [markdown]
# from sklearn.model_selection import train_test_split x = np.array(data[["type", "amount", "oldbalanceOrg", "newbalanceOrig"]]) y = np.array(data[["isFraud"]])

# %% [markdown]
# 2.	*Problem definition
# Is it:- n ongoing process
#   Payment fraud :
#
# is any dishonest or illegal activity that exploits payment systems to gain unauthorized access to funds or financial information. It encompasses various deceptive practices, such as stealing someone’s identity, making unauthorized purchases, or tricking a company into issuing refunds. The consequences of payment fraud are significant and impact individuals, businesses, and the economy as a whole:
#
# Financial losse
#
# : Fraudulent transactions can lead to substantial monetary losses for individuals, businesses, and financial institutions. These losses erode trust in payment systems and can have far-reaching effects.
# Identity theft: Payment fraud often involves the theft and misuse of personal and financial information. Victims suffer long-lasting harm, and restoring their identity and credit can be challenging.
# Business reputation: Companies that fall victim to payment fraud may experience damage to their reputation and customer trust. This can result in decreased sales, customer attrition, and increased operational costs1.
# To effectively combat payment fraud, businesses must adopt a comprehensive and proactive approach. Here are some key strategies:
#
# Fraud Detection Tech
# n-iques:
# Machine Le
#
# arning: Businesses can use machine learning algorithms to differentiate legitimate customers from fraudsters. These algorithms analyze patterns, behaviors, and data to identify suspicious activity.
# Pattern Recognition: Identifying unusual patterns in transactions can help detect fraud. For example, sudden spikes in transaction volume or repeated small transactions might indicate fraudulent
# b-ehavior.
# Data
#
# Analysis: Analyzing historical transaction data can reveal anomalies and potential fraud i
# n-dicators.
# Real-Time
# Monitoring:
# Implement innovative technologies that monitor transactions and payments in real time. This allows businesses to promptly identify and respond to suspicio
# u-s activity.
# Velocity
# -Based Rules:
# Set rules based on transaction velocity (e.g., limiting the number of transactions within a specific time frame). These rules can automatically flag potentially fraudulent
# t-ransactions2.
# Integr
# ated Solutions:
# Services like Stripe Radar use data from millions of global businesses to detect and block fraud using machine learning. These tools offer features for fraud teams, chargeback protection, and dynamic 3D Secure3.
# Remember that payment fraud detection and prevention is an ongoing process

# %% [markdown]
# 3. *Data
# -Certainly! Online payment fraud detection is a critical area in the financial industry. Let’s explore some insights and approaches related to this topic:
#
# Challenges in Online Payment Fraud Detectio
# n:
# Detecting online payment fraud involves identifying anomalies in transaction behavior. Fraudsters often behave differently during payment transactions compared to legitimate account holders.
# The data for fraud detection is highly imbalanced, with a small number of fraudulent cases compared to legitimate ones.
# Classical machine learning methods need to be extended to minimize expected financial losses while detecting f
# raud.
# Models for Fraud Dete
# ction:
# Researchers have proposed several models to address these challenges:
# Machine Learning-Based Fraud Detection: Algorithms analyze transaction data to identify suspicious patterns. These models can detect anomalies in behavior during payment transactions.
# Economic Optimization of Machine Learning Results: Optimizing machine learning models further reduces expected losses.
# Risk Model with Countermeasures: Predicting the risk of fraud while considering countermeasures helps combat fraud systematically and ec
# omically1.
# Data an
# d Features:
# Datasets for online payment fraud detection include features like customer account age, transaction value, and credit card origin.
# Hundreds of features contribute to the fraud probability, and algorithms leverage this information to mak
# predictions2.
# Impa
# ct and Losses:
# Juniper Research predicts that e-commerce, airline ticketing, money transfer, and banking services will cumulatively lose over $200 billion due to online payment fraud between 2020 and 2024.
# The increasing sophistication of fraud attempts and the growing number of attack vectors contribute t
# o these losses1.
#
# Ongoing Research:
# Researchers continue to explore data mining-based methods for online card payment fraud detection.
# Addressing fraud is crucial for maintaining a secure digital economy, especially since cards (debit and credit) remain the most popular digital payment method globally3.

# %% [markdown]
# 	Evaluation
#  etection-with-machine-learning/.
#  **Online Transaction fraud detection** is a critical area in the realm of financial security. Let's delve into some insights and approaches related to this topic.
#
# 1. **Machine Learning for Fraud Detection**:
#    - **Fraud detection** is a challenging problem because fraudulent transactions are relatively rare, yet they can lead to significant financial losses. Traditional rule-based systems are effective at uncovering known patterns but struggle with unknown schemes and sophisticated techniques.
#    - **Machine learning (ML)** plays a crucial role in enhancing fraud detection. By leveraging historical data, ML algorithms can learn from patterns and adapt to emerging fraud tactics. Here are some key points:
#      - **Data**: Having large and diverse datasets is essential for building effective ML models. More data generally leads to better fraud detection models⁶.
#      - **Multiplicity**: There is no one-size-fits-all ML algorithm. Success comes from trying various supervised and unsupervised methods, along with feature engineering techniques⁶.
#      - **Creativity**: Applying fraud analytics in novel ways, such as combining different ML methods, can improve effectiveness beyond individual approaches⁶.
#
# 2. **Research Studies and Approaches**:
#    - Several research studies have explored fraud detection using ML. Here are some notable ones:
#      - A **review article** discusses real-time fraud detection using machine learning in the context of online transactions. It covers credit card fraud, clustering cardholders based on transaction amounts, sliding window strategies, and impressive AUC values¹.
#      - An **analysis of fraud detection approaches** evaluates performance metrics from various methodologies. It identifies effective techniques for identifying online banking fraud².
#      - A study on **anomaly detection methods** assesses their performance for fraud detection using real online credit card payment data³.
#      - A **survey** proposes a taxonomy based on existing research, focusing on business impact, feature engineering, and adaptive efforts in fraud detection⁴.
#      - Another article discusses **online payment fraud**, emphasizing risk management and the role of anomaly detection⁵.
#
# 3. **Integration of Machine Learning**:
#    - Integrating ML into fraud detection involves analyzing vast amounts of data, uncovering hidden patterns, and predicting fraudulent activities before they occur⁸.
#    - ML-based fraud detection systems use algorithms trained on historical data to recognize characteristic patterns of fretection-with-machine-learning/. method globally3.

# %% [markdown]
# * feature
#
# Payment fraud detection and prevention is crucial for businesses to protect their financial assets, maintain customer confidence, and stay ahead of evolving threats. Let’s delve into the key concepts and strategies for combating payment fraud:
#
# Understanding Payment Frau
# d:
# What is payment fraud? Payment fraud refers to any dishonest or illegal activity that exploits payment systems to gain unauthorized access to funds or financial information. It includes identity theft, unauthorized purchases, and tricking companies into refunding mon
# ey.
# Impacts of Payment Fr
# aud:
# Financial lo
#
# ses: Fraudulent transactions can lead to significant monetary losses for individuals, businesses, and financial institutions, eroding trust in payment sys
# tems.
# Identity
#
# heft: Payment fraud often involves the theft and misuse of personal and financial information, causing long-lasting harm to vi
# ctims.
# Business repu
#
# ation: Companies falling victim to payment fraud may suffer damage to their reputation, customer trust, and increased operational
# costs1.
# Types of Paymen
# t Fraud:
# Credit Car
#
# d Fraud: Unauthorized use of credit card information for p
# urchases.
# Account
#
# Takeover: Gaining unauthorized access to user accounts.
# Phishing and Social Engineering: Tricking users into revealing sensitive i
# nformation.
# Frie
#
# ndly Fraud: Legitimate customers falsely claiming unauthorized t
# ransactions.
# Payment Proc
#
# essor Fraud: Exploiting vulnerabilities in payment proces
# sing systems.
# Prevention and Detecti
# on Strategies:
# Data Sec
# urity Measures:
# Implement robust data-security measures, including encryption, secure storage, and access controls.
# Monitor transactions and account activities for unusual or suspicious behavior.
# Use multifactor authentication for online accounts and transactions.
# Conduct customer identity verification, especially for high-value transactions
# or account changes.
#
# Advanced Technology:
# Modern fraud detection leverages data science, machine learning, and statistical analysis to continuously monitor transactions and assess risk.
# Models compare transactional data to
# known fraud patterns2.
#
# Real-Time Monitoring:
# Employ real-time monitoring tools to flag suspicious activities and block fraudulent attempts.
# Stripe Radar and other built-in fraud-mitigating features help monitor transac
# tions and prevent fraud1
# .
# Customized Fraud Plans:
# Create a unique payment fraud plan tailored to your business’s needs and risks.
# Assess vulnerabilities specific to your industry, customer base, and transaction volume.
# Regularly update and adapt your fraud prevention strategies. method globally3.

# %% [markdown]
# *Preparing the tools
# What is Payment Fraud?
#
# Definition: Payment fraud refers to any dishonest or illegal activity that exploits payment systems to gain unauthorized access to funds or financial information
# .
# Impact
# s:
# Financial Loss
#
# s: Fraudulent transactions can lead to significant monetary losses for individuals, businesses, and financial institutions, eroding trust in payment syste
# ms.
# Identity The
#
# ft: Payment fraud often involves the theft and misuse of personal and financial information, causing long-lasting harm to vict
# ims.
# Business Reputa
#
# ion: Companies falling victim to payment fraud may suffer damage to their reputation, leading to decreased sales and customer attrit
# ion1.
# Types of Payment
# Fraud:
# Card Not Present (CNP)
#
# Fraud: Occurs when a fraudster makes unauthorized online purchases using stolen card d
# etails.
# Account Takeove
#
#  (ATO): Involves unauthorized access to user accounts, often through phishing or credential stuffing
# attacks.
# Friend
#
# y Fraud: When a legitimate customer disputes a valid transaction, leading to cha
# rgebacks.
# Payment Inte
#
# rception: Intercepting payments during the transaction process.
# New Account Fraud: Opening fraudulent accounts using stolen
# identities.
# Mer
#
# hant Fraud: Dishonest merchants manipulating t
# ransactions.
# Mobile Pa
#
# yment Fraud: Targeting mobile payment app
# and wallets2.
# Payment Fraud Detection and Preventi
# on Strategies:
# Machine Learning and Patter
#
# n Recognition: Businesses can differentiate legitimate customers from fraudsters by leveraging machine learning, pattern recognition, and
#  data analysis.
# Veloc
#
# ty-Based Rules: Set rules to detect suspicious patterns, such as a high volume of small transactions
# in a short time.
# Real-
#
# Time Monitoring: Deploy innovative technologies that monitor real-time transacti
# ons and payments.
# Collaboration
#
# and Data Sharing: Share fraud data across businesses to enhance detec
# tion capabil
#
# ities.
# 3D Secure: Implement dynamic 3D Secure protocols
# for added security.
# Fra
#
# d Prevention Tools: Solutions like Stripe Radar use machine learning to dec
# t and block fraud34.
#
# Behavioral Analysis: Analyze customer behavior and transaction history t
# o identify anomalies.
# Geolocation and
#
# evice Fingerprinting: Use these techniques to verify the legit
# imacy of transactions.
#
# Authentication Layers: Implement multi-factor authentication (MFA) and bi
# ometric authentication.
# Regula:
#
# Training and Awareness: Educate employees and customers about fraud risks and prevention5

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy as sp
from tabulate import tabulate
import random
import tensorflow as tf

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# input/online-payment-fraud-detection/onlinefraud.csv
#
#
#  Exploratory Data Analysis

# %% [markdown]
# ### Load data

# %%
df = pd.read_csv('online transaction.csv')


df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 10 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   step            1048575 non-null  int64
#  1   type            1048575 non-null  object
#  2   amount          1048575 non-null  float64
#  3   nameOrig        1048575 non-null  object
#  4   oldbalanceOrg   1048575 non-null  float64
#  5   newbalanceOrig  1048575 non-null  float64
#  6   nameDest        1048575 non-null  object
#  7   oldbalanceDest  1048575 non-null  float64
#  8   newbalanceDest  1048575 non-null  float64
#  9   isFraud         1048575 non-null  int64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 80.0+ MB

# %% [markdown]
# #### Data exploration

# %%
df.sample(5)
# Out:
#         step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 259470    14  CASH_OUT  223463.31  C2029521498      550572.00       327108.69
# 274923    15   PAYMENT     342.13  C1766190567      391831.27       391489.13
# 332624    16   CASH_IN    7816.76  C1604715488    27400000.00     27400000.00
# 638534    35  CASH_OUT  183975.60   C550723864       57799.00            0.00
# 549807    21   PAYMENT   13788.51   C177051214         692.00            0.00
#
#            nameDest  oldbalanceDest  newbalanceDest  isFraud
# 259470  C1258812211       321437.27       544900.58        0
# 274923   M157791832            0.00            0.00        0
# 332624  C1683099061         9954.00            0.00        0
# 638534   C314150116            0.00       183975.60        0
# 549807  M1180230883            0.00            0.00        0

# %%
df.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# dtype: int64

# %%
fraud_min_max = [
    ['amount', df.amount.min(), df.amount.max()],
    ['oldbalanceOrg', df.oldbalanceOrg.min(), df.oldbalanceOrg.max()],
    ['newbalanceOrig', df.newbalanceOrig.min(), df.newbalanceOrig.max()],
    ['oldbalanceDest', df.oldbalanceDest.min(), df.oldbalanceDest.max()],
    ['isFraud', df.isFraud.min(), df.isFraud.max()]
] 

print(
    tabulate(
        fraud_min_max,
        headers=['columns', 'min value', 'max value'],
        showindex=True,
        tablefmt='github',
        numalign='right'
    )
)
# Out:
# |    | columns        |   min value |   max value |
# |----|----------------|-------------|-------------|
# |  0 | amount         |         0.1 |       1e+07 |
# |  1 | oldbalanceOrg  |           0 |    3.89e+07 |
# |  2 | newbalanceOrig |           0 |    3.89e+07 |
# |  3 | oldbalanceDest |           0 |    4.21e+07 |
# |  4 | isFraud        |           0 |           1 |

# %%
# Downcast numerical columns with smaller dtype
for col in df.columns:
    if df[col].dtype == 'float64':
        df[col] = pd.to_numeric(df[col], downcast='float')
    if df[col].dtype == 'int64':
        df[col] = pd.to_numeric(df[col], downcast='unsigned')

# Use category dtype for categorical column
df['type'] = df['type'].astype('category')

# %%
# Check duplicate values
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# .There are no duplicate values.

# %%
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (8,6)

# %% [markdown]
#  Univariate data visualization

# %%
df['step'].value_counts()
# Out:
# step
# 19    51352
# 18    49579
# 43    45060
# 15    44609
# 17    43361
#       ...
# 67        6
# 54        4
# 76        4
# 28        4
# 29        4
# Name: count, Length: 95, dtype: int64

# %%
ax = sns.countplot(x='type', data=df, palette='PuBu')
for container in ax.containers:
    ax.bar_label(container)
plt.title('Count plot of transaction type')
plt.legend(bbox_to_anchor=(1.05,1), loc='upper left')
plt.ylabel('Number of transactions')
# Out:
# C:\Users\user\abeni\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0, 0.5, 'Number of transactions')

# %% [markdown]
# Cash out is the most numerous transaction type, followed by payment, cash in, transfer and debit types.

# %%
sns.kdeplot(df['amount'], linewidth=4)
plt.title('Distribution of transaction amount')
# Out:
# C:\Users\user\abeni\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Distribution of transaction amount')

# %% [markdown]
# .The distribution of transaction amounts is right skewed.
# .This indicates that most values are clustered around the left tail of the distribution, with the   longer right tail.
# .(mode < median < mean)

# %%
df['nameOrig'].value_counts()
# Out:
# nameOrig
# C1214450722    2
# C309111136     2
# C1268675361    2
# C720460198     2
# C1109092856    2
#               ..
# C560131732     1
# C455251560     1
# C650578540     1
# C1883668225    1
# C1264356443    1
# Name: count, Length: 1048317, dtype: int64

# %% [markdown]
# There are 1048317 initial customers, and every step has at least 1 occurrence.

# %%
sns.kdeplot(df['oldbalanceOrg'], linewidth=4)
plt.title('Distribution of transaction amount')
# Out:
# C:\Users\user\abeni\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Distribution of transaction amount')

# %% [markdown]
# .The distribution of pre-transaction balances of the initial customers is right skewed.

# %%
sns.kdeplot(df['newbalanceOrig'], linewidth=4)
plt.title('Distribution of transaction amount')
# Out:
# C:\Users\user\abeni\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Distribution of transaction amount')

# %% [markdown]
# .The distribution of post-transaction balances of the initial customers is right skewed.

# %%
df['nameDest'].value_counts()
# Out:
# nameDest
# C985934102     98
# C1286084959    96
# C1590550415    89
# C248609774     88
# C665576141     87
#                ..
# M382871047      1
# M322765556      1
# M1118794441     1
# M1127250627     1
# M677577406      1
# Name: count, Length: 449635, dtype: int64

# %% [markdown]
# There are 449635 recipients, and every step has at least 1 occurrence.

# %%
sns.kdeplot(df['oldbalanceDest'], linewidth=4)
plt.title('Distribution of transaction amount')
# Out:
# C:\Users\user\abeni\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Distribution of transaction amount')

# %% [markdown]
# .The distribution of pre-transaction balances of the recipient is right skewed.

# %%
sns.kdeplot(df['newbalanceDest'], linewidth=4)
plt.title('Distribution of transaction amount')
# Out:
# C:\Users\user\abeni\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Distribution of transaction amount')

# %% [markdown]
# .The distribution of post-transaction balances of the recipient is right skewed.

# %%
ax = sns.countplot(x='isFraud', data=df, palette='PuBu')
for container in ax.containers:
    ax.bar_label(container)
plt.title('Count plot of fraud transaction')
plt.ylabel('Number of transactions')

del ax

# %% [markdown]
# .There are much more non-fraudulent transactions than fraudulent transactions.

# %%
fig, ax = plt.subplots(1,2,figsize=(20,5))

sns.countplot(x='type', data=df, hue='isFraud', palette='PuBu', ax=ax[0])
for container in ax[0].containers:
    ax[0].bar_label(container)
ax[0].set_title('Count plot of transaction type')
ax[0].legend(loc='best')
ax[0].set_ylabel('Number of transactions')

df2 = df.groupby(['type', 'isFraud']).size().unstack()
df2.apply(lambda x : round(x/sum(x)*100, 2), axis=1).plot(kind='barh', stacked=True, color=['lightsteelblue', 'steelblue'], ax=ax[1])
for container in ax[1].containers:
    ax[1].bar_label(container, label_type='center')
ax[1].set_title('Count plot of transaction type')
ax[1].legend(bbox_to_anchor=(1.05,1), loc='upper left')
ax[1].set_ylabel('Number of transactions')
ax[1].grid(axis='y')
# Out:
# C:\Users\user\abeni\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\user\abeni\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 3
#       1 fig, ax = plt.subplots(1,2,figsize=(20,5))
# ...

# %% [markdown]
# .Fraudulent transactions only occur in debit and transfer types.

# %%
df['quantity'] = pd.cut(df['amount'], 5, labels=['very low', 'low', 'moderate', 'high', 'very high'])

ax = sns.countplot(x='quantity', data=df, hue='isFraud', palette='PuBu')
for container in ax.containers:
    ax.bar_label(container)
plt.title('Count plot of amount quantity')
plt.legend(bbox_to_anchor=(1.05,1), loc='upper left')
plt.ylabel('Number of transactions')
# Out:
# C:\Users\user\abeni\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\user\abeni\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 3
#       1 df['quantity'] = pd.cut(df['amount'], 5, labels=['very low', 'low', 'moderate', 'high', 'very high'])
# ...

# %% [markdown]
# .All fraudulent transactions fall into the category of very low amounts.
#
# .This suggests that in most cases, small transactions are more prone to fraudulent transactions.

# %%
df1 = df[df['isFraud']==1]
df2 = df1['step'].value_counts().head(10)
ax = df2.plot(kind='bar', color='lightsteelblue')
for container in ax.containers:
    ax.bar_label(container)
plt.title('Top 10 steps that often lead to fraudulent transactions')
plt.ylabel('Number of fraudulent transactions')
plt.xlabel('Step')
plt.grid(axis='x')

del ax, df2

# %% [markdown]
# .Step 66 has the highest number of fraudulent transactions, 40 cases.
#
# .This indicates that Step 66 is the step that will most likely lead to fraudulent transactions.

# %%
df2 = df1['nameOrig'].value_counts().head(10)
ax = df2.plot(kind='bar', color='lightsteelblue')
for container in ax.containers:
    ax.bar_label(container)
plt.title('Top 10 initial customers fall for a fraudulent transactions')
plt.ylabel('Number of fraudulent transactions')
plt.xlabel('Initial customers')
plt.grid(axis='x')

del ax, df2

# %% [markdown]
# .Initial customers are scammed of at most one for a fraudulent transaction.

# %%
df2 = df1['nameDest'].value_counts().head(10)
ax = df2.plot(kind='bar', color='lightsteelblue')
for container in ax.containers:
    ax.bar_label(container)
plt.title('Top 10 recipients highly involved in fraudulent transactions')
plt.ylabel('Number of fraudulent transactions')
plt.xlabel('Recipients')
plt.grid(axis='x')

del ax, df2

# %% [markdown]
# .Suspicious recipients only have a maximum of 2 involved fraudulent transactions.

# %%
df['oldbalanceDest_amt'] = pd.cut(df['oldbalanceDest'], 5, labels=['very low', 'low', 'moderate', 'high', 'very high'])

ax = sns.countplot(x='oldbalanceDest', data=df, hue='isFraud', palette='PuBu')
for container in ax.containers:
    ax.bar_label(container)
plt.title('Count plot of recipients pre-transaction balance amount')
plt.legend(bbox_to_anchor=(1.05,1), loc='upper left')
plt.ylabel('Number of transactions')
plt.xlabel('Recipient pre-transaction balance amount')
# Out:
# C:\Users\user\abeni\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\user\abeni\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 3
#       1 df['oldbalanceDest_amt'] = pd.cut(df['oldbalanceDest'], 5, labels=['very low', 'low', 'moderate', 'high', 'very high'])
# ...

# %% [markdown]
# .Recipients with very low pre-transaction balances has the highest number of fraudulent transactions.
#
# .This implies that recipients with very low pre-transaction balances may be more susceptible to fraudulent transactions.

# %% [raw]
#  . Model Building

# %%
# Data preprocessing
df['type'] = df['type'].map({'PAYMENT':0, 'CASH_IN':1, 'DEBIT':2, 'CASH_OUT':3, 'TRANSFER':4})

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report, roc_curve, auc, ConfusionMatrixDisplay


seed = 42
np.random.seed(seed)
random.seed(seed)
tf.random.set_seed(seed)


X = df.copy()
X.drop(['nameOrig', 'newbalanceOrig', 'nameDest', 'newbalanceDest', 'quantity', 'oldbalanceOrg_amt', 'oldbalanceDest_amt'], axis=1, inplace=True)
y = X.pop('isFraud')


# Stratified train-test split
skfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
for train_idx, test_idx in skfold.split(X,y):
    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]


sc = StandardScaler()
scaled_train = sc.fit_transform(X_train)
scaled_test = sc.transform(X_test)
X_train = pd.DataFrame(scaled_train, index=X_train.index, columns=X_train.columns)
X_test = pd.DataFrame(scaled_test, index=X_test.index, columns=X_test.columns)


X_train, y_train = RandomUnderSampler(sampling_strategy='majority').fit_resample(X_train, y_train)

# %%
def model_comparison_evaluate(classifiers, X, y):
    print('K-Fold Cross-Validation:\n')
    for name, model in classifiers.items():
        print('{}:'.format(name))
        
        scoring = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc']
        
        for score in scoring:
            scores = cross_val_score(model, X, y, scoring=score, cv=skfold, n_jobs=-1)
            print('Mean {} score: {:.3f} ({:.3f})'.format(score, scores.mean(), scores.std()))
            
        print('\n')

# %%
classifiers = { 'Random Forest Classifier':RandomForestClassifier(class_weight='balanced', random_state=seed),
                'Logistic Regression': LogisticRegression(class_weight='balanced', random_state=seed)
              }

# %% [markdown]
# *Evaluating your model, beyond the default score() evaluator
# For classification

# %%
model_comparison_evaluate(classifiers, X_train, y_train)
# Out:
# K-Fold Cross-Validation:
#
# Random Forest Classifier:
# Mean accuracy score: 0.963 (0.008)
# Mean precision score: 0.957 (0.015)
# Mean recall score: 0.969 (0.007)
# Mean f1 score: 0.963 (0.008)
# Mean roc_auc score: 0.994 (0.001)
#
#
# Logistic Regression:
# Mean accuracy score: 0.836 (0.020)
# Mean precision score: 0.828 (0.026)
# Mean recall score: 0.850 (0.021)
# Mean f1 score: 0.839 (0.019)
# Mean roc_auc score: 0.925 (0.010)

# %%
model = RandomForestClassifier(class_weight='balanced', random_state=seed)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
y_pred_score = model.predict_proba(X_test)[:,1]
print('Random Forest Classifier:')
print(classification_report(y_pred, y_test, labels=[0,1], target_names=['Non-Fraud [0]', 'Fraud [1]']), '\n')



fig, ax = plt.subplots(1, 2, figsize=(20,5))
ax[0].set_title('Confusion Matrix of Random Forest Model:')
ConfusionMatrixDisplay.from_predictions(y_test, y_pred, colorbar=False, values_format='', cmap='crest', ax=ax[0])
ax[0].grid(False)



fpr, tpr, thresholds = roc_curve(y_test, y_pred_score)
roc_auc = auc(fpr, tpr)                       
ax[1].set_title('ROC Curve - Random Forest Classifier')
ax[1].plot(fpr, tpr, label = 'AUC = %0.3f' % roc_auc, c='steelblue')
ax[1].plot([0,1],[0,1],'--', c='lightsteelblue')
ax[1].legend(loc='lower right')
ax[1].set_ylabel('True Positive Rate')
ax[1].set_xlabel('False Positive Rate')
# Out:
# Random Forest Classifier:
#                precision    recall  f1-score   support
#
# Non-Fraud [0]       0.96      1.00      0.98    200673
#     Fraud [1]       0.97      0.02      0.05      9042
#
#      accuracy                           0.96    209715
#     macro avg       0.97      0.51      0.51    209715
#  weighted avg       0.96      0.96      0.94    209715
# Text(0.5, 0, 'False Positive Rate')

# %% [markdown]
# .From the confusion matrix, 200667 were correctly classified as non-fraudulent payments, and 8819 people were misclassified as non-fraudulent payments.
#
# .According to the confusion matrix, 223 payments were incorrectly labelled as fraud while 6 payments were correctly identified as fraud.

# %% [markdown]
#   Conclusion

# %% [markdown]
# .Random Forest obtains the highest score of all using K-fold cross-validation.
#
# .The best performing model is Random Forest for identifying fraudulent and non-fraudulent payments, as the AUC is 0.999, which is close to 1. This means it has a good separability measure, and the model has an 99.9% chance of being able to distinguish between positive and negative classes..
